# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/deekshitha0007/fly-rank/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#My Lane (Refresh / Content Opportunity Scoring)
#I chose the Refresh / Content Opportunity Scoring lane because I want to identify content pages that should be reviewed first for improvement. Instead of trying to predict Google's algorithm, my goal is to use observable search and engagement data to rank pages that may benefit from content updates. This can help prioritize limited review time and support better content decisions.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# The Question

# Research Question:
# Which content pages should be reviewed first based on search performance and engagement signals?

# Decision:
# Decide which pages should be prioritized for content refresh or improvement.

# Action:
# A content manager or SEO analyst reviews the highest-ranked pages and decides whether to refresh, expand, monitor, or improve them.

# Cost of a Wrong Recommendation:
# If the recommendation is wrong, valuable pages might be ignored while unnecessary effort is spent reviewing pages that do not need changes. This wastes time and resources.

# Why ML Helps:
# The dataset contains many pages and multiple performance signals. Machine learning can identify useful patterns and rank pages more consistently than manual inspection.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#The dataset contains 104 clients,519,606 content items, and over 78 million daily performance records in the warehouse release. The starter dataset also includes multiple search and engagement metrics such as impressions, clicks, CTR, sessions, and content age. This amount of data makes manual prioritization difficult and supports using ML to rank content review opportunities.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#This work is intended to provide decision support based on observed search and engagement signals. The analysis can identify patterns that may help prioritize content review, but it cannot prove that refreshing a page will improve search performance. The results are observational and should be combined with human judgment before any action is taken.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
